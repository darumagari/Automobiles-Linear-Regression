# %%
import sklearn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime

# %% [markdown]
# Version of Libraries being used

# %%
print(np.__version__)
# Out:
# 1.15.4

# %%
print(sklearn.__version__)
# Out:
# 0.20.1

# %% [markdown]
# Import the Dataset

# %%
automobile_df = pd.read_csv('/Users/darumagari/desktop/Janani Ravi/AutoMpg Dataset/auto-mpg.csv')

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 46   22.0          4         140.0         72    2408          19.0
# 15   22.0          6         198.0         95    2833          15.5
# 371  29.0          4         135.0         84    2525          16.0
# 378  38.0          4         105.0         63    2125          14.7
# 303  31.8          4          85.0         65    2020          19.2
#
#      model year  origin                car name
# 46           71       1     chevrolet vega (sw)
# 15           70       1         plymouth duster
# 371          82       1          dodge aries se
# 378          82       1  plymouth horizon miser
# 303          79       3              datsun 210

# %%
automobile_df.shape
# Out:
# (398, 9)

# %%
automobile_df = automobile_df.replace('?',np.nan)

# %%
automobile_df = automobile_df.dropna()

# %%
automobile_df.shape
# Out:
# (392, 9)

# %%
automobile_df.drop(['origin','car name'],axis =1,inplace = True)

# %%
automobile_df.shape
# Out:
# (392, 7)

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 151  31.0          4          79.0         67    2000          16.0
# 309  41.5          4          98.0         76    2144          14.7
# 232  16.0          8         351.0        149    4335          14.5
# 387  38.0          6         262.0         85    3015          17.0
# 329  44.6          4          91.0         67    1850          13.8
#
#      model year
# 151          74
# 309          80
# 232          77
# 387          82
# 329          80

# %%
automobile_df['model year'] = '19' + automobile_df['model year'].astype(str)

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration model year
# 365  20.2          6         200.0         88    3060          17.1       1981
# 157  15.0          8         350.0        145    4440          14.0       1975
# 286  17.6          8         302.0        129    3725          13.4       1979
# 101  23.0          6         198.0         95    2904          16.0       1973
# 142  26.0          4          79.0         67    1963          15.5       1974

# %%
automobile_df['age'] = datetime.datetime.now().year - pd.to_numeric(automobile_df['model year'])

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 378  38.0          4         105.0         63    2125          14.7
# 243  21.5          3          80.0        110    2720          13.5
# 302  34.5          4         105.0         70    2150          14.9
# 102  26.0          4          97.0         46    1950          21.0
# 290  15.5          8         351.0        142    4054          14.3
#
#     model year  age
# 378       1982   38
# 243       1977   43
# 302       1979   41
# 102       1973   47
# 290       1979   41

# %%
automobile_df.drop(['model year'],axis =1,inplace = True)

# %%
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  age
# 96   13.0          8         360.0        175    3821          11.0   47
# 268  27.2          4         119.0         97    2300          14.7   42
# 278  31.5          4          89.0         71    1990          14.9   42
# 9    15.0          8         390.0        190    3850           8.5   50
# 47   19.0          6         250.0        100    3282          15.0   49

# %%
automobile_df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# age               int64
# dtype: object

# %%
automobile_df['horsepower'] = pd.to_numeric(automobile_df['horsepower'], errors ='coerce')

# %%
automobile_df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# age               int64
# dtype: object

# %%
automobile_df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration         age
# count    392.000000  392.000000
# mean      15.541327   44.020408
# std        2.758864    3.683737
# min        8.000000   38.000000
# 25%       13.775000   41.000000
# 50%       15.500000   44.000000
# 75%       17.025000   47.000000
# max       24.800000   50.000000

# %%
fig, ax = plt.subplots(figsize=(12,8))

# %%
plt.scatter(automobile_df['age'],automobile_df['mpg'])

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(automobile_df['age'],automobile_df['mpg'])

plt.xlabel('Age')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(automobile_df['acceleration'],automobile_df['mpg'])

plt.xlabel('Acceleration')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(automobile_df['weight'],automobile_df['mpg'])

plt.xlabel('Weight')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(automobile_df['displacement'],automobile_df['mpg'])

plt.xlabel('Displacement')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(automobile_df['horsepower'],automobile_df['mpg'])

plt.xlabel('horsepower')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %%
automobile_df.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# age          -0.580541   0.345647      0.369855    0.416361  0.309120
#
#               acceleration       age
# mpg               0.423329 -0.580541
# cylinders        -0.504683  0.345647
# displacement     -0.543800  0.369855
# horsepower       -0.689196  0.416361
# weight           -0.416839  0.309120
# acceleration      1.000000 -0.290316
# age              -0.290316  1.000000

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.heatmap(automobile_df.corr(),annot = True)

# %%
automobile_df = automobile_df.sample(frac=1).reset_index(drop=True)

# %%
automobile_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 0  18.0          6         199.0          97    2774          15.5   50
# 1  23.0          4          97.0          54    2254          23.5   48
# 2  26.0          4          97.0          75    2265          18.2   43
# 3  11.0          8         318.0         210    4382          13.5   50
# 4  38.1          4          89.0          60    1968          18.8   40

# %%
automobile_df.to_csv('/Users/darumagari/desktop/Janani Ravi/AutoMpg Dataset/auto-mpg-processed.csv',index=False)

# %%
# !ls datasets
# Out:
# ls: datasets: No such file or directory

# %%
from sklearn.model_selection import train_test_split

X = automobile_df[['horsepower']]
Y = automobile_df[['mpg']]

x_train,x_test, y_train, y_test = train_test_split(X,Y,test_size = 0.2)

# %%
x_train.sample(5)
# Out:
#      horsepower
# 38          100
# 137         160
# 171         150
# 116          68
# 155          90

# %%
y_test.sample(5)
# Out:
#       mpg
# 146  20.0
# 202  13.0
# 178  26.6
# 347  14.0
# 93   26.8

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression(normalize = True).fit(x_train,y_train)

# %%
print('Training score:', linear_model.score(x_train,y_train))
# Out:
# Training score: 0.5944368843330994

# %%
y_pred = linear_model.predict(x_test)

# %%
from sklearn.metrics import r2_score

print('Testing score:', r2_score(y_test,y_pred))
# Out:
# Testing score: 0.6508514737000598

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(x_test,y_test)
plt.plot(x_test, y_pred, color = 'r')

plt.xlabel('horsepower')
plt.ylabel('MPG')
plt.show()

# %%
X = automobile_df[['age']]
Y = automobile_df[['mpg']]

x_train,x_test, y_train, y_test = train_test_split(X,Y,test_size = 0.2)

linear_model = LinearRegression(normalize = True).fit(x_train,y_train)

print('Training score:', linear_model.score(x_train,y_train))

y_pred = linear_model.predict(x_test)

print('Testing score:', r2_score(y_test,y_pred))
# Out:
# Training score: 0.326194748329233
# Testing score: 0.3777864188179121

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(x_test,y_test)
plt.plot(x_test, y_pred, color = 'r')

plt.xlabel('age')
plt.ylabel('MPG')
plt.show()

# %%
X = automobile_df[['displacement','horsepower','weight']]
Y = automobile_df[['mpg']]

x_train,x_test, y_train, y_test = train_test_split(X,Y,test_size = 0.2)

linear_model = LinearRegression(normalize = True).fit(x_train,y_train)

print('Training score:', linear_model.score(x_train,y_train))
# Out:
# Training score: 0.6995566289734131

# %%
y_pred = linear_model.predict(x_test)

print('Testing score:', r2_score(y_test,y_pred))
# Out:
# Testing score: 0.7323330656714763

# %%
plt.figure(figsize = (20,10))

plt.plot(y_pred, label = 'Predicted')
plt.plot(y_test.values, label = 'Actual')

plt.ylabel('Mpg')

plt.legend()
plt.show()

# %%
X = automobile_df[['displacement','horsepower','weight','acceleration','cylinders']]
Y = automobile_df[['mpg']]

x_train,x_test, y_train, y_test = train_test_split(X,Y,test_size = 0.2)

linear_model = LinearRegression(normalize = True).fit(x_train,y_train)

print('Training score:', linear_model.score(x_train,y_train))

y_pred = linear_model.predict(x_test)

print('Testing score:', r2_score(y_test,y_pred))
# Out:
# Training score: 0.7009524265008522
# Testing score: 0.734611800121441

# %%
plt.figure(figsize = (20,10))

plt.plot(y_pred, label = 'Predicted')
plt.plot(y_test.values, label = 'Actual')

plt.ylabel('Mpg')

plt.legend()
plt.show()

# %%
import statsmodels.api as sm

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Lars
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
result_dict = {}

# %%
def build_model(regression_fn,
               name_of_y_col,
               names_of_x_cols,
               dataset,
               test_frac=0.2,
               preprocess_fn=None,
               show_plot_Y=False,
               show_plot_scatter=False):
    
    X = dataset[names_of_x_cols]
    Y = dataset[name_of_y_col]
    
    if preprocess_fn is not None:
        X = preprocess_fn(X)
        
    x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size = test_frac)
    
    model = regression_fn(x_train,y_train)
    
    y_pred = model.predict(x_test)
    
    print('Training_score :', model.score(x_train,y_train))
    print('Test_score :', r2_score(y_test,y_pred))
    
    if show_plot_Y == True:
        fig, ax=  plt.subplots(figsize = (12,8))

        plt.plot(y_pred, label = 'Predicted')
        plt.plot(y_test.values, label = 'Actual')

        plt.ylabel(name_of_y_col)

        plt.legend()
        plt.show()
        
    if show_plot_scatter == True:
        fig, ax=  plt.subplots(figsize = (12,8))

        plt.scatter(x_test,y_test)
        plt.plot(x_test,y_pred,'r')

        plt.legend(['Predicted line','Obsserved data'])
        plt.show()
        
    return {
            'training_score': model.score(x_train,y_train),
            'test_score': r2_score(y_test,y_pred)
            }

# %%
def compare_results():
    for key in result_dict:
        print('Regression:', key)
        print('Training score', result_dict[key]['training_score'])
        print('Test score', result_dict[key]['test_score'])
        print()

# %%
def linear_reg(x_train,y_train):
    model = LinearRegression(normalize = True)
    model.fit(x_train,y_train)
    
    return model

# %%
result_dict['mpg ~ single_linear'] = build_model(linear_reg,
                                                'mpg',
                                                ['weight'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Training_score : 0.705247284555129
# Test_score : 0.6207172990172442

# %%
result_dict['mpg ~ kitchen_sink_linear'] = build_model(linear_reg,
                                                'mpg',
                                                ['displacement','horsepower','weight','acceleration','cylinders'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Training_score : 0.7077958543563474
# Test_score : 0.698897076869446

# %%
result_dict['mpg ~ parsimonious_linear'] = build_model(linear_reg,
                                                'mpg',
                                                ['horsepower','weight'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Training_score : 0.6907482681045908
# Test_score : 0.7587017837151067

# %%
compare_results()
# Out:
# Regression: mpg ~ single_linear
# Training score 0.705247284555129
# Test score 0.6207172990172442
#
# Regression: mpg ~ kitchen_sink_linear
# Training score 0.7030171255547341
# Test score 0.7211480532276179
#
# Regression: mpg ~ parsimonious_linear
# Training score 0.6907482681045908
# Test score 0.7587017837151067

# %%
def lasso_reg(x_train,y_train, alpha = 0.5):
    model = Lasso(alpha=alpha)
    model.fit(x_train,y_train)
    
    return model

# %%
result_dict['mpg ~ kitchen_sink_lasso'] = build_model(lasso_reg,
                                                'mpg',
                                                ['displacement','horsepower','weight','acceleration','cylinders'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Training_score : 0.7180378201263586
# Test_score : 0.6666716279146198

# %%
compare_results()
# Out:
# Regression: mpg ~ single_linear
# Training score 0.705247284555129
# Test score 0.6207172990172442
#
# Regression: mpg ~ kitchen_sink_linear
# Training score 0.7077958543563474
# Test score 0.698897076869446
#
# Regression: mpg ~ parsimonious_linear
# Training score 0.6907482681045908
# Test score 0.7587017837151067
#
# Regression: mpg ~ kitchen_sink_lasso
# Training score 0.7180378201263586
# Test score 0.6666716279146198

# %%
def ridge_reg(x_train,y_train, alpha = 0.5, normalize = True):
    model = Ridge(alpha=alpha, normalize=normalize)
    model.fit(x_train,y_train)
    
    return model

# %%
result_dict['mpg ~ kitchen_sink_ridge'] = build_model(ridge_reg,
                                                'mpg',
                                                ['displacement','horsepower','weight','acceleration','cylinders'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Training_score : 0.6948287966756604
# Test_score : 0.6115789155611538

# %%
compare_results()
# Out:
# Regression: mpg ~ single_linear
# Training score 0.705247284555129
# Test score 0.6207172990172442
#
# Regression: mpg ~ kitchen_sink_linear
# Training score 0.7077958543563474
# Test score 0.698897076869446
#
# Regression: mpg ~ parsimonious_linear
# Training score 0.6907482681045908
# Test score 0.7587017837151067
#
# Regression: mpg ~ kitchen_sink_lasso
# Training score 0.7180378201263586
# Test score 0.6666716279146198
#
# Regression: mpg ~ kitchen_sink_ridge
# Training score 0.6948287966756604
# Test score 0.6115789155611538

# %%
def elastic_net_reg(x_train,y_train, alpha = 1, l1_ratio=0.5, normalize = False, max_iter=100000, warm_start=True, 
                   equivalent_to="Elastic Net"):
    print("Equivalent to:", equivalent_to)
    
    model = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, normalize=normalize,
                      max_iter = max_iter, warm_start=warm_start )
    model.fit(x_train,y_train)
    
    return model

# %%
from functools import partial

result_dict['mpg ~ kitchen_sink_elestic_net_ols'] = build_model(partial(elastic_net_reg,alpha=0, equivalent_to ="OLS"),
                                                'mpg',
                                                ['displacement','horsepower','weight','acceleration','cylinders'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Equivalent to: OLS
# Training_score : 0.7240282004047512
# Test_score : 0.6247610918470814

# %%
result_dict['mpg ~ kitchen_sink_elestic_net_lasso'] = build_model(partial(elastic_net_reg,alpha=1, l1_ratio=1
                                                                          , equivalent_to ="Lasso"),
                                                'mpg',
                                                ['displacement','horsepower','weight','acceleration','cylinders'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Equivalent to: Lasso
# Training_score : 0.7097866270231246
# Test_score : 0.6898647391289592

# %%
result_dict['mpg ~ kitchen_sink_elestic_net_ridge'] = build_model(partial(elastic_net_reg,alpha=1, l1_ratio=0
                                                                          , equivalent_to ="Ridge"),
                                                'mpg',
                                                ['displacement','horsepower','weight','acceleration','cylinders'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Equivalent to: Ridge
# Training_score : 0.714315072321248
# Test_score : 0.6712828498012907

# %%
result_dict['mpg ~ kitchen_sink_elastic_net'] = build_model(partial(elastic_net_reg,alpha=1, l1_ratio=0.5
                                                                          , equivalent_to ="ElasticNet"),
                                                'mpg',
                                                ['displacement','horsepower','weight','acceleration','cylinders'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Equivalent to: ElasticNet
# Training_score : 0.6923187716016788
# Test_score : 0.7764943489043625

# %%
compare_results()
# Out:
# Regression: mpg ~ single_linear
# Training score 0.705247284555129
# Test score 0.6207172990172442
#
# Regression: mpg ~ kitchen_sink_linear
# Training score 0.7077958543563474
# Test score 0.698897076869446
#
# Regression: mpg ~ parsimonious_linear
# Training score 0.6907482681045908
# Test score 0.7587017837151067
#
# Regression: mpg ~ kitchen_sink_lasso
# Training score 0.7180378201263586
# Test score 0.6666716279146198
#
# Regression: mpg ~ kitchen_sink_ridge
# Training score 0.6948287966756604
# Test score 0.6115789155611538
#
# Regression: mpg ~ kitchen_sink_elestic_net_ols
# Training score 0.7240282004047512
# Test score 0.6247610918470814
#
# Regression: mpg ~ kitchen_sink_elestic_net_lasso
# Training score 0.7097866270231246
# Test score 0.6898647391289592
#
# Regression: mpg ~ kitchen_sink_elestic_net_ridge
# Training score 0.714315072321248
# Test score 0.6712828498012907
#
# Regression: mpg ~ kitchen_sink_elastic_net
# Training score 0.6923187716016788
# Test score 0.7764943489043625

# %%
def svr_reg(x_train,y_train, kernel='linear', epsilon=0.05, C=0.3):
    model = SVR(kernel=kernel, epsilon=epsilon, C=C)
    model.fit(x_train,y_train)
    
    return model

# %%
result_dict['mpg ~ kitchen_sink_svr'] = build_model(svr_reg,
                                                'mpg',
                                                ['displacement','horsepower','weight','acceleration','cylinders'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Training_score : 0.701368583385334
# Test_score : 0.6472675009496381

# %%
compare_results()
# Out:
# Regression: mpg ~ single_linear
# Training score 0.705247284555129
# Test score 0.6207172990172442
#
# Regression: mpg ~ kitchen_sink_linear
# Training score 0.7077958543563474
# Test score 0.698897076869446
#
# Regression: mpg ~ parsimonious_linear
# Training score 0.6907482681045908
# Test score 0.7587017837151067
#
# Regression: mpg ~ kitchen_sink_lasso
# Training score 0.7180378201263586
# Test score 0.6666716279146198
#
# Regression: mpg ~ kitchen_sink_ridge
# Training score 0.6948287966756604
# Test score 0.6115789155611538
#
# Regression: mpg ~ kitchen_sink_elestic_net_ols
# Training score 0.7240282004047512
# Test score 0.6247610918470814
#
# Regression: mpg ~ kitchen_sink_elestic_net_lasso
# Training score 0.7097866270231246
# Test score 0.6898647391289592
#
# Regression: mpg ~ kitchen_sink_elestic_net_ridge
# Training score 0.714315072321248
# Test score 0.6712828498012907
#
# Regression: mpg ~ kitchen_sink_elastic_net
# Training score 0.6923187716016788
# Test score 0.7764943489043625
#
# Regression: mpg ~ kitchen_sink_svr
# Training score 0.701368583385334
# Test score 0.6472675009496381

# %%
def kneighbors_reg(x_train,y_train, n_neighbors=10):
    model = KNeighborsRegressor(n_neighbors=n_neighbors)
    model.fit(x_train,y_train)
    
    return model

# %%
result_dict['mpg ~ kitchen_sink_kneighbors'] = build_model(kneighbors_reg,
                                                'mpg',
                                                ['displacement','horsepower','weight','acceleration','cylinders'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Training_score : 0.7594268973039618
# Test_score : 0.7133231670438205

# %%
compare_results()
# Out:
# Regression: mpg ~ single_linear
# Training score 0.705247284555129
# Test score 0.6207172990172442
#
# Regression: mpg ~ kitchen_sink_linear
# Training score 0.7077958543563474
# Test score 0.698897076869446
#
# Regression: mpg ~ parsimonious_linear
# Training score 0.6907482681045908
# Test score 0.7587017837151067
#
# Regression: mpg ~ kitchen_sink_lasso
# Training score 0.7180378201263586
# Test score 0.6666716279146198
#
# Regression: mpg ~ kitchen_sink_ridge
# Training score 0.6948287966756604
# Test score 0.6115789155611538
#
# Regression: mpg ~ kitchen_sink_elestic_net_ols
# Training score 0.7240282004047512
# Test score 0.6247610918470814
#
# Regression: mpg ~ kitchen_sink_elestic_net_lasso
# Training score 0.7097866270231246
# Test score 0.6898647391289592
#
# Regression: mpg ~ kitchen_sink_elestic_net_ridge
# Training score 0.714315072321248
# Test score 0.6712828498012907
#
# Regression: mpg ~ kitchen_sink_elastic_net
# Training score 0.6923187716016788
# Test score 0.7764943489043625
#
# Regression: mpg ~ kitchen_sink_svr
# Training score 0.701368583385334
# Test score 0.6472675009496381
#
# Regression: mpg ~ kitchen_sink_kneighbors
# Training score 0.7594268973039618
# Test score 0.7133231670438205

# %%
def apply_standard_scaler(x):
    scaler = StandardScaler()
    scaler.fit(x)
    
    return scaler.transform(x)

# %%
def sgd_reg(x_train,y_train,max_iter=10000,tol=1e-3):
    model = SGDRegressor(max_iter=max_iter, tol=tol)
    model.fit(x_train,y_train)
    
    return model

# %%
result_dict['mpg ~ kitchen_sink_sgd'] = build_model(sgd_reg,
                                                'mpg',
                                                ['displacement','horsepower','weight','acceleration','cylinders'],
                                                automobile_df,
                                                show_plot_Y= True,
                                                preprocess_fn=apply_standard_scaler)
# Out:
# Training_score : 0.7141613331026346
# Test_score : 0.675113983753605

# %%
def decision_tree_reg(x_train,y_train,max_depth=2):
    model = DecisionTreeRegressor(max_depth=max_depth)
    model.fit(x_train,y_train)
    
    return model

# %%
result_dict['mpg ~ kitchen_sink_decision_tree'] = build_model(decision_tree_reg,
                                                'mpg',
                                                ['displacement','horsepower','weight','acceleration','cylinders'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Training_score : 0.747102725437772
# Test_score : 0.6391690739301392

# %%
def lars_reg(x_train,y_train,n_nonzero_coefs=4):
    model = Lars(n_nonzero_coefs=n_nonzero_coefs)
    model.fit(x_train,y_train)
    
    return model

# %%
result_dict['mpg ~ kitchen_sink_lars'] = build_model(lars_reg,
                                                'mpg',
                                                ['displacement','horsepower','weight','acceleration','cylinders'],
                                                automobile_df,
                                                show_plot_Y= True)
# Out:
# Training_score : 0.7031801274629046
# Test_score : 0.7214926174225622

# %%
compare_results()
# Out:
# Regression: mpg ~ single_linear
# Training score 0.705247284555129
# Test score 0.6207172990172442
#
# Regression: mpg ~ kitchen_sink_linear
# Training score 0.7077958543563474
# Test score 0.698897076869446
#
# Regression: mpg ~ parsimonious_linear
# Training score 0.6907482681045908
# Test score 0.7587017837151067
#
# Regression: mpg ~ kitchen_sink_lasso
# Training score 0.7180378201263586
# Test score 0.6666716279146198
#
# Regression: mpg ~ kitchen_sink_ridge
# Training score 0.6948287966756604
# Test score 0.6115789155611538
#
# Regression: mpg ~ kitchen_sink_elestic_net_ols
# Training score 0.7240282004047512
# Test score 0.6247610918470814
#
# Regression: mpg ~ kitchen_sink_elestic_net_lasso
# Training score 0.7097866270231246
# Test score 0.6898647391289592
#
# Regression: mpg ~ kitchen_sink_elestic_net_ridge
# Training score 0.714315072321248
# Test score 0.6712828498012907
#
# Regression: mpg ~ kitchen_sink_elastic_net
# Training score 0.6923187716016788
# Test score 0.7764943489043625
#
# Regression: mpg ~ kitchen_sink_svr
# Training score 0.701368583385334
# Test score 0.6472675009496381
#
# Regression: mpg ~ kitchen_sink_kneighbors
# Training score 0.7594268973039618
# Test score 0.7133231670438205
#
# Regression: mpg ~ kitchen_sink_sgd
# Training score 0.7141613331026346
# Test score 0.675113983753605
#
# Regression: mpg ~ kitchen_sink_decision_tree
# Training score 0.747102725437772
# Test score 0.6391690739301392
#
# Regression: mpg ~ kitchen_sink_lars
# Training score 0.7031801274629046
# Test score 0.7214926174225622
